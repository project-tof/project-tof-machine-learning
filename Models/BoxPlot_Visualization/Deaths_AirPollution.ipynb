# %%
import pandas as pd

pd.set_option('display.max_columns', 140)
pd.set_option('display.max_rows', 140)
data = pd.read_csv('C:/Users/victo/Documents/projects/project-tof-ML/project-tof-machine-learning/datas/death-rates-from-air-pollution.csv')

data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Air pollution - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                         299.477309
# 1                                         291.277967
# 2                                         278.963056
# 3                                         278.790815
# 4                                         287.162923
#
#    Deaths - Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                         250.362910
# 1                                         242.575125
# 2                                         232.043878
# 3                                         231.648134
# 4                                         238.837177
#
#    Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)  \
# ...

# %%
data.shape
# Out:
# (6468, 7)

# %%
data.dtypes
# Out:
# Entity                                                                                           object
# Code                                                                                             object
# Year                                                                                              int64
# Deaths - Air pollution - Sex: Both - Age: Age-standardized (Rate)                               float64
# Deaths - Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)    float64
# Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)        float64
# Deaths - Ambient ozone pollution - Sex: Both - Age: Age-standardized (Rate)                     float64
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# Entity                                                                                            0
# Code                                                                                            980
# Year                                                                                              0
# Deaths - Air pollution - Sex: Both - Age: Age-standardized (Rate)                                 0
# Deaths - Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)      0
# Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)          0
# Deaths - Ambient ozone pollution - Sex: Both - Age: Age-standardized (Rate)                       0
# dtype: int64

# %%
data.drop('Code', axis = 1, inplace = True)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 5))
data.boxplot(column = ["Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)"])
plt.show()

# %%
x = data['Year'].astype(float)
y = data['Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)']

print(y)
# Out:
# 0       46.446589
# 1       46.033841
# 2       44.243766
# 3       44.440148
# 4       45.594328
#           ...
# 6463    27.589603
# 6464    26.760618
# 6465    25.715415
# 6466    25.643570
# 6467    26.166182
# Name: Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate), Length: 6468, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x = x.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 3)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', size = 12)

xreg = np.arange(1990, 2020, 1)

fig, ax = plt.subplots(figsize=(10, 5))
fig.subplots_adjust(bottom=0.15, left=0.2)
ax.plot(x, y)
ax.set_title('Particulate matter pollution')
ax.set_xlabel('Time (year)')
ax.set_ylabel('Deaths - Ambient particulate matter pollution')

plt.show()
