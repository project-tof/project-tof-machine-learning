# %%
import pandas as pd

pd.set_option('display.max_columns', 100)
data = pd.read_csv('C:/Users/victo/Documents/projects/project-tof-ML/project-tof-machine-learning/datas/Environment_Temperature_change_E_All_Data_NOFLAG.csv', encoding = "ISO-8859-1")

data.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  Y1964  Y1965  Y1966  Y1967  \
# 0  Temperature change   °C  0.777  0.062  2.744 -5.232  1.868  3.629 -1.432
# 1  Standard Deviation   °C  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919 -0.202 -0.096  3.397  0.296
# 3  Standard Deviation   °C  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  1.659 -0.909 -0.069 -0.759
#
#    Y1968  Y1969  Y1970  Y1971  Y1972  Y1973  Y1974  Y1975  Y1976  Y1977  \
# ...

# %%
data.drop('Area', axis = 1, inplace = True)
data.drop('Area Code', axis = 1, inplace = True)
data.drop('Months Code', axis = 1, inplace = True)
data.drop('Element Code', axis = 1, inplace = True)
data.drop('Element', axis = 1, inplace = True)
data.drop('Unit', axis = 1, inplace = True)
data.drop('Months', axis = 1, inplace = True)

# %%
y = data.iloc[0]

# %%
import numpy as np 
   
x = np.array(np.arange(1961, 2020, 1));

# for i in range(1961, 2020, 1):
#     x.append(i)
x = x.reshape(-1, 1)

y.shape
# Out:
# (59,)

# %%
x.shape
# Out:
# (59, 1)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import normalize


model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
x.shape
print(y)
# Out:
# Y1961    0.777
# Y1962    0.062
# Y1963    2.744
# Y1964   -5.232
# Y1965    1.868
# Y1966    3.629
# Y1967   -1.432
# Y1968    0.389
# Y1969   -2.298
# Y1970    0.804
# Y1971   -1.487
# Y1972   -1.305
# Y1973   -2.951
# Y1974   -1.184
# Y1975   -0.490
# Y1976    2.409
# Y1977   -3.014
# Y1978   -0.663
# Y1979    1.141
# Y1980   -0.393
# Y1981    1.724
# Y1982    0.678
# Y1983    0.524
# Y1984   -0.058
# Y1985    0.435
# Y1986    0.332
# Y1987    2.655
# Y1988    1.150
# Y1989   -1.108
# Y1990    0.634
# Y1991    0.018
# Y1992    0.582
# Y1993   -0.821
# Y1994    1.087
# Y1995    1.297
# Y1996   -0.718
# Y1997    1.426
# Y1998    0.950
# Y1999    0.859
# Y2000    1.565
# Y2001   -0.603
# Y2002    1.606
# Y2003    2.479
# Y2004    2.707
# Y2005    0.109
# Y2006   -1.606
# Y2007    0.431
# Y2008   -5.553
# Y2009    1.518
# Y2010    3.601
# Y2011    1.179
# Y2012   -0.583
# Y2013    1.233
# Y2014    1.755
# Y2015    1.943
# Y2016    3.416
# Y2017    1.201
# Y2018    1.996
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', size = 16)

fig, ax = plt.subplots(figsize=(10, 5))
fig.subplots_adjust(bottom=0.15, left=0.2)
ax.plot(x, y)
ax.set_title('Predicting the world average temperature')
ax.set_xlabel('time (years)')
ax.set_ylabel('World Average Temperature')
# Out:
# Text(0, 0.5, 'World Average Temperature')
